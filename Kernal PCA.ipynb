# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# %%
X,y=make_moons(n_samples=100,random_state=None)

# %%
plt.scatter(X[y==0,0],X[y==0,1],color='red',marker='^',alpha=0.5)
plt.scatter(X[y==1,0],X[y==1,1],color='blue',marker="o",alpha=0.5)
plt.title('A nonlinear data set')
plt.xlabel('x coordinate')
plt.ylabel('y coordinate')
plt.show()

# %%
from sklearn.decomposition import PCA,KernelPCA

# %%
my_pca=PCA(n_components=2)
X_pca=my_pca.fit_transform(X)
plt.scatter(X_pca[y==0,0], X_pca[y==0,1], color='red', marker='^',  alpha=0.5)
plt.scatter(X_pca[y==1,0],  X_pca[y==1,1], color='blue', marker='o', alpha=0.5)
plt.show()

# %%
import numpy as np
my_pca=PCA(n_components=1)
X_pca=my_pca.fit_transform(X)
plt.scatter(X[y==0,0],np.zeros((50,1))+0.2,color='red',alpha=0.5)
plt.scatter(X[y==0,1],np.zeros((50,1))-0.2,color='blue',alpha=0.5)
plt.show()

# %%
my_Kpca=KernelPCA(n_components=2,gamma=15,kernel='rbf')
X_Kpca=my_Kpca.fit_transform(X)
plt.figure(figsize=(8,6))
plt.scatter(X_Kpca[y==0,0],X_Kpca[y==0,1],color='RED',alpha=0.5)
plt.scatter(X_Kpca[y==1,0],X_Kpca[y==1,1],color='Blue',alpha=0.5)
plt.text(-0.35,0.35,'gamma=15',fontsize=12)
plt.show()

# %%
my_pca=KernelPCA(n_components=1,kernel='rbf',gamma=15)
X_kpca=my_pca.fit_transform(X)
plt.scatter(X_kpca[y==0,0],np.zeros((50,1)),color='red',alpha=0.5)
plt.scatter(X_kpca[y==1,0],np.zeros((50,1)),color='blue',alpha=0.5)
plt.show()

# %%
X[y==0,0]
# Out:
# array([-0.90096887, -0.22252093,  0.71834935, -0.28452759, -0.71834935,
#         0.96729486,  0.22252093, -0.34536505,  0.99794539, -0.98155916,
#         0.98155916, -0.40478334, -0.1595999 , -0.99794539,  0.34536505,
#        -0.94905575, -1.        ,  0.90096887, -0.57211666,  0.03205158,
#         0.8380881 , -0.99179001,  0.51839257,  0.92691676,  0.80141362,
#        -0.67230089,  0.6234898 ,  0.57211666,  0.46253829, -0.6234898 ,
#         0.67230089,  0.09602303,  1.        , -0.80141362,  0.40478334,
#        -0.96729486,  0.99179001,  0.94905575, -0.03205158, -0.51839257,
#        -0.09602303, -0.76144596, -0.8713187 , -0.92691676, -0.46253829,
#         0.28452759, -0.8380881 ,  0.8713187 ,  0.1595999 ,  0.76144596])
